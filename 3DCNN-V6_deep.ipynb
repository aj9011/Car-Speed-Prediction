# %%
import numpy as np
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import pandas as pd
#import ipywidgets as widgets
#from IPython.html.widgets import *
import pickle
import h5py 
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Activation, Dropout, Flatten, Dense, Lambda
from keras.layers import ELU
from keras.optimizers import Adam
import keras.backend.tensorflow_backend as KTF
from keras.backend.tensorflow_backend import set_session
import cv2
from tqdm import tqdm_notebook
import skvideo.io
import imutils
from keras.models import load_model
from keras.layers import Input, Dense, Lambda, add, LSTM, TimeDistributed, concatenate
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras.layers.normalization import BatchNormalization
from keras.layers import Conv1D, MaxPooling1D,  GlobalAveragePooling1D
import glob
from keras.layers.convolutional import Conv3D
from keras.layers.pooling import MaxPooling3D
#from imgaug import augmenters as iaa
from keras.layers import ZeroPadding3D

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ['CUDA_VISIBLE_DEVICES'] = '0,3'

# %matplotlib inline
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 1.0
set_session(tf.Session(config=config))

# %%
def imshow_2(img):
    plt.imshow(img)
    plt.show()
    
def read_ylabel(y_label_path):
    train_y = []
    f = open(y_label_path, 'r')
    lines = f.readlines()
    for line in lines:
        line = line.replace('\n','')        
        train_y.append(float(line))
    train_y = pd.DataFrame(train_y)set_session
    train_y['prediction']=0
    train_y['error']=0
    train_y = train_y.reset_index()
    train_y.columns= ['index','real','prediction','error']
    return train_y

# %%
def crop_image(image) :
    h, w, _ = image.shape
    
    h_bottom = h-int(h*0.10)
    h_top = int(h*0.50)
    
    w_crop_size = int(w*0.15)
    
    return image[h_top:h_bottom, w_crop_size:(w-w_crop_size)]

def crop_or_pad(image, size=(299, 299)) :
        
    image = image.astype(np.float32)
    h, w = image.shape[:2]
    window = (0, 0, h, w)
    scale = 1
    padding = [(0, 0), (0, 0), (0, 0)]

    image_max = max(h, w)
    scale = float(max(size)) / image_max
    image = cv2.resize(image, (int(w * scale), int(h * scale)))

    h, w = image.shape[:2]
    top_pad = (size[1] - h) // 2
    bottom_pad = size[1] - h - top_pad
    left_pad = (size[0] - w) // 2
    right_pad = size[0] - w - left_pad
    padding = [(top_pad, bottom_pad), (left_pad, right_pad), (0, 0)]
    image = np.pad(image, padding, mode='constant', constant_values=0)

    # Fix image normalization
    image /= float(np.nanmax(image))

    return image

# %%
sometime = lambda aug: iaa.Sometimes(0.3, aug)
sequence = iaa.Sequential([ # sometime(iaa.GaussianBlur((0, 1.5))), # blur images with a sigma between 0 and 3.0
                            # sometime(iaa.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5))), # sharpen images
                            # sometime(iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 3.), per_channel=0.5)), # add gaussian noise to images
                            sometime(iaa.Dropout((0.0, 0.1))), # randomly remove up to 10% of the pixels
                            sometime(iaa.CoarseDropout((0.0, 0.1), size_percent=(0.01, 0.02), per_channel=0.2)),
                            # sometime(iaa.Add((-10, 10), per_channel=0.5)), # change brightness of images (by -10 to 10 of original value)
                          ],
                          random_order=True # do all of the above in random order
                         )

# %%
def normalize(image):
    return image - [104.00699, 116.66877, 122.67892]

def augment(image, flip, bright_factor):
    # random disturbances borrowed from IAA
    image = sequence.augment_image(image)
    
    # random brightness change
    hsv_image = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    hsv_image[:,:,2] = hsv_image[:,:,2] * bright_factor
    image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)
    
    # random flip (vertical axis)
    if flip:
        image = cv2.flip(image, 1)
                
    return image

# %%
data = pd.read_csv('../etc/476_0511.csv')

# %%
data.shape
# Out:
# (476, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(data, test_size=0.05, random_state=0)
df_train=df_train.reset_index(drop=True)
df_test=df_test.reset_index(drop=True)

# %%
df_test.shape
# Out:
# (24, 3)

# %%
df_train.shape
# Out:
# (452, 3)

# %%
def preprocess_image(image):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cropped_image = crop_image(img)
    cropped_image = cropped_image / 255.0
    #image = cv2.resize(cropped_image, (120, 60))
    return cropped_image

# %%
img = preprocess_image(frame)
imshow_2(img)
# Out:
# errorTraceback (most recent call last)
# <ipython-input-85-9401ecf456ac> in <module>
# ----> 1 img = preprocess_image(frame)
#       2 imshow_2(img)
#
# <ipython-input-84-8e115ed34355> in preprocess_image(image)
#       1 def preprocess_image(image):
# ----> 2     img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       3     cropped_image = crop_image(img)
#       4     cropped_image = cropped_image / 255.0
#       5     #image = cv2.resize(cropped_image, (120, 60))
#
# error: OpenCV(4.1.0) ../modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
def preprocess_image_2(image):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cropped_image = crop_image(img)
    image = cv2.resize(cropped_image, (120, 60))
    img_3 = normalize(image)
    return img_3

# %%
def preprocess_image(image):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cropped_image = crop_image(img)
    image = cv2.resize(cropped_image, (120, 60))
    #img_2 = image.astype(np.float32)
    #img_3 = preprocess(img_2)
    return image

# %%
normalize

# %%
img.shape
# Out:
# (60, 120, 3)

# %%
imshow_2(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imgg = img[30:60, :]
imshow_2(imgg)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imgg.shape
# Out:
# (30, 120, 3)

# %%
data.shape
# Out:
# (476, 3)

# %%
data[:5]
# Out:
#    Unnamed: 0                                             videos  \
# 0           0  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 1           1  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 2           2  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 3           3  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 4           4  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
#
#                                                speed
# 0  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 1  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 2  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 3  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 4  /notebooks/AJ_car-speed/blackbox/labeling_tota...

# %%
data['videos'][0]
# Out:
# '/notebooks/AJ_car-speed/blackbox/klumblr_bbox_new_data/choi/20190404_after/AlwaysMovie/alwa_20190404_144337_F.MP4'

# %%
cap = cv2

# %%
data = pd.read_csv('../etc/476_0511.csv')

# %%
data[:5]
# Out:
#    Unnamed: 0                                             videos  \
# 0           0  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 1           1  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 2           2  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 3           3  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 4           4  ../klumblr_bbox_new_data/choi/20190404_after/A...
#
#                                                speed
# 0  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 1  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 2  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 3  /notebooks/AJ_car-speed/blackbox/labeling_tota...
# 4  /notebooks/AJ_car-speed/blackbox/labeling_tota...

# %%
data['videos'][0]
# Out:
# '/notebooks/AJ_car-speed/blackbox/klumblr_bbox_new_data/choi/20190404_after/AlwaysMovie/alwa_20190404_144337_F.MP4'

# %%
data['videos'] = data['videos'].replace('/notebooks/AJ_car-speed/blackbox','..')

# %%
for i in range(len(data)):
    data['videos'][i] = data['videos'][i].replace('/notebooks/AJ_car-speed/blackbox','..')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['videos'] = data['videos'].replace('/notebooks/AJ_car-speed/blackbox','..')

# %%
data['speed'][0]
# Out:
# '/notebooks/AJ_car-speed/blackbox/labeling_total/labeling_daylight_highstd_0504/labeling_0404/alwa_20190404_144337_F.MP4.txt'

# %%
y_train = read_ylabel(data['speed'][45])
y_train
# Out:
#       index       real  prediction  error
# 0         0  64.000000           0      0
# 1         1  64.000000           0      0
# 2         2  64.000000           0      0
# 3         3  64.000000           0      0
# 4         4  64.000000           0      0
# 5         5  64.000000           0      0
# 6         6  64.000000           0      0
# 7         7  64.000000           0      0
# 8         8  64.000000           0      0
# 9         9  64.000000           0      0
# 10       10  64.000000           0      0
# 11       11  64.000000           0      0
# 12       12  64.000000           0      0
# 13       13  64.000000           0      0
# 14       14  64.000000           0      0
# 15       15  64.000000           0      0
# 16       16  64.000000           0      0
# 17       17  64.000000           0      0
# 18       18  64.000000           0      0
# 19       19  64.000000           0      0
# 20       20  64.000000           0      0
# ...

# %%
for i in range(len(data)):
    data['speed'][i] = data['speed'][i].replace('/notebooks/AJ_car-speed/blackbox','..')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
y_train = read_ylabel('../labeling_total/labeling_daylight_highstd_0504/labeling_0504/alwa_20190502_120310_F.MP4.txt')
y_train
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-120-3e6fe0b54327> in <module>
# ----> 1 y_train = read_ylabel('../labeling_total/labeling_daylight_highstd_0504/labeling_0504/alwa_20190502_120310_F.MP4.txt')
#       2 y_train
#
# <ipython-input-5-f69cd45062fe> in read_ylabel(y_label_path)
#       5 def read_ylabel(y_label_path):
#       6     train_y = []
# ----> 7     f = open(y_label_path, 'r')
#       8     lines = f.readlines()
#       9     for line in lines:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../labeling_total/labeling_daylight_highstd_0504/labeling_0504/alwa_20190502_120310_F.MP4.txt'

# %%
data
# Out:
#      Unnamed: 0                                             videos  \
# 0             0  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 1             1  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 2             2  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 3             3  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 4             4  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 5             5  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 6             6  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 7             7  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 8             8  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 9             9  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 10           10  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 11           11  ../klumblr_bbox_new_data/choi/20190404_after/A...
# 12           12  ../klumblr_bbox_new_data/choi/20190404_after/A...
# ...

# %%
data.to_csv('0906_data')

# %%
aa=data['videos'][0]

# %%
aa = aa.replace('/notebooks/AJ_car-speed/blackbox','..')
aa
# Out:
# '../klumblr_bbox_new_data/choi/20190404_after/AlwaysMovie/alwa_20190404_144337_F.MP4'

# %%
def preprocess_image(image):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cropped_image = crop_image(img)
    cropped_image = cropped_image / 255.0
    image = cv2.resize(cropped_image, (120, 60))
    return image

# %%
cap = cv2.VideoCapture(data['videos'][36])
ret, frame = cap.read()
print(ret)
imshow_2(frame)
# Out:
# True

# %%
aa = preprocess_image(frame)
imshow_2(aa)

# %%
aa = preprocess_image(frame)
imshow_2(aa)

# %%
cap = cv2.VideoCapture('alwa_20190605_183020_F.MP4')
ret, frame = cap.read()
print(ret)
imshow_2(frame)
# Out:
# True

# %%
cap = cv2.VideoCapture('/notebooks/AJ_car_speed/blackbox/klumblr_bbox_new_data/choi/20190404_after/AlwaysMovie/alwa_20190605_183020_F.MP4')
ret, frame = cap.read()
print(ret)
imshow_2(frame)
# Out:
# False
# TypeErrorTraceback (most recent call last)
# <ipython-input-46-11f2822f9db3> in <module>
#       2 ret, frame = cap.read()
#       3 print(ret)
# ----> 4 imshow_2(frame)
#
# <ipython-input-5-f69cd45062fe> in imshow_2(img)
#       1 def imshow_2(img):
# ----> 2     plt.imshow(img)
#       3     plt.show()
#       4
#       5 def read_ylabel(y_label_path):
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
def preprocess_image(image):
    img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cropped_image = crop_image(img)
    image = cv2.resize(cropped_image, (120, 60))
    #img_2 = image.astype(np.float32)
    #img_3 = preprocess(img_2)
    return image

# %%
cap = cv2.VideoCapture(data['videos'][250])
for i in range(10):
    
    ret, frame = cap.read()
    #imshow_2(frame)

    img = preprocess_image(frame)
    imgg = img[30:60, :]
    imshow_2(imgg)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-82-ae9d45fb1cee> in <module>
#       5     #imshow_2(frame)
#       6
# ----> 7     img = preprocess_image(frame)
#       8     imgg = img[30:60, :]
#       9     imshow_2(imgg)
#
# NameError: name 'preprocess_image' is not defined

# %%
cap = cv2.VideoCapture(data['videos'][400])
ret, frame = cap.read()
imshow_2(frame)
img = preprocess_image(frame)
imshow_2(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_2 = img.astype(np.float32)
img_3 = preprocess(img_2)
imshow_2(img_3)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_3.shape
# Out:
# (60, 120, 3)

# %%
np.mean(img[..., 0])
# Out:
# 153.23140495867767

# %%
np.std(img[..., 0])
# Out:
# 47.93074124064149

# %%
def preprocess(img):
    img[..., 0] -= np.mean(img[..., 0])
    img[..., 1] -= np.mean(img[..., 1])
    img[..., 2] -= np.mean(img[..., 2])
    img[..., 0] /= np.std(img[..., 0])
    img[..., 1] /= np.std(img[..., 1])
    img[..., 2] /= np.std(img[..., 2])
    return img

# %%
cap = cv2.VideoCapture(data['videos'][400])
ret, frame = cap.read()
imshow_2(frame)
img = preprocess_image(frame)
imshow_2(img)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-f4a8de3caa6d> in <module>()
#       2 ret, frame = cap.read()
#       3 imshow_2(frame)
# ----> 4 img = preprocess_image(frame)
#       5 imshow_2(img)
#
# NameError: name 'preprocess_image' is not defined

# %%
data
# Out:
#      Unnamed: 0                                             videos  \
# 0             0  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 1             1  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 2             2  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 3             3  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 4             4  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 5             5  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 6             6  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 7             7  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 8             8  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 9             9  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 10           10  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 11           11  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 12           12  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# ...

# %%
def generate_data(data, batch_size):
    image_batch = np.zeros((batch_size,timesteps, 60, 120,3))# nvidia input params
    label_batch = np.zeros((batch_size, 10))
    while True:
        
        v_idx = np.random.randint(len(data))
        cap = cv2.VideoCapture(data['videos'][v_idx])
        y_train = read_ylabel(data['speed'][v_idx])
        
        for i in range(batch_size):
            
            length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            idx = np.random.randint(0, length - 17)
            cap.set(1,idx);
            
            for t in range(timesteps):
                ret, frame = cap.read()
                if ret != True:
                    break
                image = preprocess_image(frame)
                image_batch[i,t] = image
                
            y = ([np.mean(y_train['real'][idx:idx+timesteps])])
            label_batch[i] = y

        yield(image_batch, label_batch)

# %%
def c3d_model():
    input_Shape = (16,112, 112,3)
    
    model = Sequential()
    # model.add(Lambda(lambda x: x/ 127.5 - 1, input_shape = input_Shape))
    
    # 1st layer group
    model.add(Conv3D(64, (3, 3, 3),  activation='relu', padding='same', name='conv1', input_shape = input_Shape))
    model.add(Conv3D(64, (3, 3, 3),  activation='relu', padding='same', name='conv1b'))
    model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), padding='valid', name='pool1'))

    # 2nd layer group
    model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same', name='conv2'))
    model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same', name='conv2b'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool2'))


    # 3rd layer group
    model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same', name='conv3a'))
    model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same', name='conv3b'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool3'))
    
    # 4th layer group
    model.add(Conv3D(512, (3, 3, 3), activation='relu', padding='same', name='conv4a'))
    model.add(Conv3D(512, (3, 3, 3), activation='relu', padding='same', name='conv4b'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool4'))

    # 5th layer group
    model.add(Conv3D(512, (3, 3, 3), activation='relu', padding='same', name='conv5a'))
    model.add(Conv3D(512, (3, 3, 3), activation='relu', padding='same', name='conv5b'))
    model.add(ZeroPadding3D(padding=((0, 0), (0, 1), (0, 1)), name='zeropad5'))
    model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool5'))
    model.add(Flatten())

    # FC layers group
    model.add(Dense(4096, activation='relu', name='fc6'))
    model.add(Dropout(.6))
    model.add(Dense(4096, activation='relu', name='fc7'))
    model.add(Dropout(.6))
    model.add(Dense(10,    activation='linear', name='fc8'))
    
    # Optimizer
    adam = Adam(lr=1e-4)

    # Compile
    model.compile(loss='mse',
                  optimizer=adam)

    # Summary
    model.summary()
    return model

# %%
model = c3d_model()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1 (Conv3D)               (None, 16, 112, 112, 64)  5248
# _________________________________________________________________
# conv1b (Conv3D)              (None, 16, 112, 112, 64)  110656
# ...

# %%
from keras.callbacks import ReduceLROnPlateau

# %%
model_name = '3DCNN-V6_deep_0906'
batch_size = 4
num_epochs = 45
steps_per_epoch = 300
timesteps = 16

run_name = 'model={}-batch_size={}--timesteps={}-num_epoch={}-steps_per_epoch={}'.format(model_name,
                                                                          batch_size,
                                                                          timesteps,
                                                                          num_epochs,
                                                                          steps_per_epoch)

filepath = "../model_total/3DCNN-V6_deep/nom_model-{epoch:02d}"+run_name+".hdf5"

earlyStopping = EarlyStopping(monitor='val_loss', 
                              patience=35, 
                              verbose=1, 
                              min_delta = 0.23,
                              mode='min',)

modelCheckpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, min_lr=1e-6,
                              patience=3, verbose=1, cooldown=1)

#modelCheckpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)

#tensorboard = TensorBoard(log_dir='/notebooks/AJ_car-speed/블랙박스영상_match/3DCNN_model/tensor_b', histogram_freq=0,
                            # write_graph=True, write_images=True)

callbacks_list = [modelCheckpoint,earlyStopping, reduce_lr]

# %%
df_test.shape
# Out:
# (24, 3)

# %%
df_train.shape
# Out:
# (454, 3)

# %%
print('   one epoch : ', steps_per_epoch * timesteps * batch_size)
print('   total epoch : ', num_epochs * steps_per_epoch * timesteps * batch_size)
print('   total images : ', 428 * 30 * 180)
# Out:
#    one epoch :  38400
#    total epoch :  1728000
#    total images :  2311200

# %%
#model.save('my_model.h5')
model = load_model('../model_total/C3D_deep_0508_model/daylight_model-22model=C3D_deep_0508_model-batch_size=5--timesteps=16-num_epoch=30-steps_per_epoch=300.hdf5')

# %%
train_generator = generate_data(df_train, batch_size)
valid_generator = generate_data(df_test, batch_size)

# %%
history = model.fit_generator(
        train_generator,
        steps_per_epoch = steps_per_epoch,
        epochs = num_epochs,
        callbacks = callbacks_list,
        verbose = 1,
        validation_data = valid_generator,
        validation_steps = int(steps_per_epoch/5))

print(history)
# Out:
# Epoch 1/45
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-119-6a426ace8a56> in <module>
#       6         verbose = 1,
#       7         validation_data = valid_generator,
# ----> 8         validation_steps = int(steps_per_epoch/5))
#       9
#      10 print(history)
#
# /opt/conda/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
# ...

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'lr'])

# %%
# saving history
pickle.dump(history.history, open('../model_total/3DCNN-V6_deep/0512_his.p', "wb"))
history = pickle.load(open('../model_total/3DCNN-V6_deep/0512_his.p', "rb" ))

# %%
history
# Out:
# {'loss': [1969.2111028079987,
#   1327.2223052825927,
#   1178.964038394928,
#   913.8857104868889,
#   717.1612000064849,
#   575.4122500627637,
#   460.01472032976153,
#   423.82476242256166,
#   380.6445017943382,
#   363.7299028577805,
#   385.85344738578794,
#   325.8492553219795,
#   303.9371134080887,
#   294.8039732341766,
#   322.9297077302933,
#   248.18113461112975,
#   227.7255426197052,
#   216.92195014500618,
#   248.73595789980888,
#   212.42400714159012,
#   187.79516146564484,
#   202.79244949436188,
#   227.44559120988845,
#   234.65592120045423,
#   209.07389981269836,
#   201.90787423563003,
#   221.02980664896964,
#   215.69722575378418,
#   209.90995478773118,
#   213.38212243819237,
#   175.39203491067886,
#   213.93510624432562,
#   210.97934578877687,
#   196.51367528152466,
#   196.86761396229267,
#   205.75264519166947,
#   182.9062106513977,
#   213.0494402292371,
#   221.9778348956108,
#   200.97327655673027,
#   214.82874585461616,
# ...

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'lr'])

# %%
df_test
# Out:
#     Unnamed: 0                                             videos  \
# 0          141  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 1          142  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 2          274  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 3           60  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 4          303  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 5          146  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 6           37  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 7          158  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 8           74  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 9          234  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 10         100  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 11          45  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# 12         249  /notebooks/AJ_car-speed/blackbox/klumblr_bbox_...
# ...

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical flow')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['lr', 'loss', 'val_mean_squared_error', 'val_loss', 'mean_squared_error'])

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical flow')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'lr'])

# %%
# saving history
pickle.dump(history.history, open('../model_total/C3D_deep_0508_model/0508_his.p', "wb"))

# %%
# saving history
pickle.dump(history.history, open('../model_total/C3D_deep_0508_model/0508_his.p', "wb"))
history = pickle.load(open('../model_total/C3D_deep_0508_model/0508_his.p', "rb" ))

# %%
history
# Out:
# {'loss': [1874.2802462848028,
#   843.1449517409006,
#   671.2502497299512,
#   453.40260281125705,
#   403.5529928421974,
#   358.97969418863454,
#   279.37239043911296,
#   267.95146394352116,
#   242.50942717909814,
#   196.22168072971206,
#   200.1952808656295,
#   188.71427532956005,
#   207.3350317553679,
#   180.12085878531138,
#   188.62344243486723,
#   179.8320237392187,
#   162.70661560753982,
#   159.32678009028237,
#   127.63114592790603,
#   160.49576213558515,
#   172.18176682313285,
#   146.55600358724595,
#   130.7019371951806,
#   127.99436779260635,
#   132.61714299350976,
#   120.44288381174206,
#   89.21668764753888,
#   95.43725880420456,
#   114.10589911439146,
#   89.21331851257632],
#  'lr': [1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   3e-05,
#   8.999999e-06,
#   8.999999e-06,
#   8.999999e-06,
# ...

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical flow')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'lr', 'val_loss'])

# %%
history
# Out:
# {'loss': [115.23339006503423,
#   137.95167144616445,
#   140.80917850573857,
#   111.53595770041147,
#   111.65298588911692,
#   83.81997581382592,
#   98.29668113251527,
#   130.53866393725076,
#   92.01429477214813,
#   105.64668774604797,
#   83.90591547648113,
#   97.20673613071442,
#   107.2822729186217,
#   96.50342085401218,
#   102.01877410729726,
#   88.01742130080859,
#   111.70232671538989,
#   95.04575299421946,
#   86.53848387658596,
#   88.14183521986007,
#   97.41202201684315,
#   83.73750113964081,
#   88.19589759007096,
#   111.42425268332164,
#   85.29711529831091,
#   89.57196828166644,
#   89.9937010105451,
#   89.07989896059036,
#   106.55835351069769,
#   98.54268936594327,
#   74.14365664641062,
#   82.94435736298561,
#   70.53556657354036,
#   71.16012604395549,
#   79.62962910016378],
#  'val_loss': [167.24003631273905,
#   270.9870170911153,
#   219.72353010177613,
#   183.92716296513876,
#   107.2840075413386,
#   298.4538929700851,
# ...

# %%
history_df = pd.DataFrame(history)

# %%
plt.plot(history_df)

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical flow')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
# saving history
pickle.dump(history.history, open('../model_total/3DCNN_model/r3_0430_his.p', "wb"))

# %%
history = pickle.load(open('../model_total/3DCNN_model/r3_0430_his.p', "rb" ))

# %%
history
# Out:
# {'loss': [107.16972896337509,
#   105.18219207465648,
#   93.69764555652937,
#   98.94140992800395,
#   103.24187707424164,
#   110.92826686779658,
#   104.16631142059963,
#   106.38071619868279,
#   94.3286596695582,
#   90.5026659021775,
#   94.84441130638123,
#   90.31312700013319,
#   120.07709872722626,
#   119.31110704819362,
#   77.92794262886048,
#   81.74145521481832,
#   114.25161120732625,
#   109.50544930140177,
#   73.72022937734921,
#   87.96218642234803,
#   77.28732540448506,
#   100.28303045471509,
#   109.46788299878439,
#   87.33960583964983,
#   77.54824931820234,
#   88.65779193401336,
#   78.11004968166351,
#   80.52217386404674,
#   99.04923344135284,
#   91.09580142021179,
#   79.68456901788711,
#   62.623202141523365,
#   84.64946743249894,
#   79.5510547876358,
#   86.63373302459716],
#  'val_loss': [273.9678449471792,
#   186.61880402565004,
#   153.692040681839,
#   193.0985068957011,
#   334.72784551779426,
#   202.67562935352325,
#   192.50571642716724,
# ...

# %%
history_df = pd.DataFrame(history)

# %%
history_df
# Out:
#            loss     val_loss
# 0   1437.247000  1635.536281
# 1   1157.539035  1809.766326
# 2   1013.661393  1100.570130
# 3    665.390278  1341.916134
# 4    461.729117  1043.794023
# 5    405.316613   555.678444
# 6    369.054024   701.616276
# 7    374.376615   601.523421
# 8    327.052660   731.263827
# 9    303.759761   775.946518
# 10   276.010137   448.486369
# 11   321.088878   513.813177
# 12   280.034098   446.019068
# 13   252.112833   688.660661
# 14   271.135309   467.494307
# 15   233.887211   585.025938
# 16   221.669026   746.617307
# 17   231.473901   554.622677
# 18   212.317360   346.428839
# 19   218.731998   702.608202
# 20   223.082443   546.948508
# 21   210.206895   555.216097
# 22   213.128952   411.457761
# 23   205.622916   427.865674
# 24   198.577608   996.847065
# 25   211.762642   551.983766
# 26   188.480379   824.662408
# 27   203.421819   522.006189
# 28   195.749723   983.425150
# 29   176.053110   538.076912
# 30   170.836420   737.291273
# ...

# %%
plt.plot(history_df)

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('optical flow')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-99-42c67e63c7ce> in <module>()
# ----> 1 print(history.history.keys())
#       2
#       3 ### plot the training and validation loss for each epoch
#       4 plt.plot(history.history['loss'])
#       5 plt.plot(history.history['val_loss'])
#
# AttributeError: 'dict' object has no attribute 'history'

# %%
#model.save('my_model.h5')
model = load_model('3DCNN_model/model-06model=3DCNN_model-batch_size=10--timesteps=10-num_epoch=50-steps_per_epoch=500.hdf5')

# %%
timesteps = 10
75, 224,3

# %%
def prediction(data_path, y_path):
    image_batch = np.zeros((timesteps, 75, 224, 3))# nvidia input params
    label_batch = np.zeros((timesteps, 1))
    
    cap = cv2.VideoCapture(data_path)
    train_y = read_ylabel(y_path)
    speed_dict = train_y.to_dict()

    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    for j in tqdm_notebook(range(16320,20400)):
        for t in range(timesteps):
            ret, old_frame = cap.read()
            if ret != True:
                break

            img= preprocess_image_from_path(data_path, old_frame)
            image_batch[t] = img
            
        img_diff = image_batch.reshape(1,image_batch.shape[0], image_batch.shape[1], image_batch.shape[2], image_batch.shape[3])

        prediction = model.predict(img_diff)

        error = abs(prediction-train_y['real'][11+j])

        speed_dict['prediction'][11+j] = float(prediction[0][0])
        speed_dict['error'][11+j] = float(error[0][0])
    return speed_dict

# %%
data.head()
# Out:
#    Unnamed: 0                                              speed  \
# 0           0  /notebooks/AJ_car-speed/블랙박스영상_match/labeling_...
# 1           1  /notebooks/AJ_car-speed/블랙박스영상_match/labeling_...
# 2           2  /notebooks/AJ_car-speed/블랙박스영상_match/labeling_...
# 3           3  /notebooks/AJ_car-speed/블랙박스영상_match/labeling_...
# 4           4  /notebooks/AJ_car-speed/블랙박스영상_match/labeling_...
#
#                                                video
# 0  /notebooks/AJ_car-speed/klumblr_bbox_new_data/...
# 1  /notebooks/AJ_car-speed/klumblr_bbox_new_data/...
# 2  /notebooks/AJ_car-speed/klumblr_bbox_new_data/...
# 3  /notebooks/AJ_car-speed/klumblr_bbox_new_data/...
# 4  /notebooks/AJ_car-speed/klumblr_bbox_new_data/...

# %%
def prediction(v_idx):
    image_batch = np.zeros((timesteps, 75, 224,3))# nvidia input params
    cap = cv2.VideoCapture(data['video'][v_idx])
    y_train = read_ylabel(data['speed'][v_idx])
    speed_dict = y_train.to_dict()
    length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    y=[]
    for i in tqdm_notebook(range(100)):
        for t in range(timesteps):
            ret, frame = cap.read()
            if ret != True:
                break
            frame=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            cropped_image = crop_image(frame)
            image = crop_or_pad(cropped_image, size=(224, 224))
            image_2 = image[75:150,:]

            image_batch[t] = image_2
            
        img_diff = image_batch.reshape(1,image_batch.shape[0], image_batch.shape[1], image_batch.shape[2], image_batch.shape[3])

        prediction = model.predict(img_diff)
        error = abs(prediction-y_train['real'][11+i])

        speed_dict['prediction'][11+i] = float(prediction[0][0])
        speed_dict['error'][11+i] = float(error[0][0])

    speed_dict_df = pd.DataFrame(speed_dict) 
    return speed_dict_df

# %%
image_batch = np.zeros((timesteps, 75, 224,3))# nvidia input params
cap = cv2.VideoCapture(data['video'][90])
y_train = read_ylabel(data['speed'][90])
speed_dict = y_train.to_dict()
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# %%
for i in tqdm_notebook(range(1)):
    for t in range(timesteps):
        ret, frame = cap.read()
        if ret != True:
            break
        frame=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        cropped_image = crop_image(frame)
        image = crop_or_pad(cropped_image, size=(224, 224))
        image_2 = image[75:150,:]

        image_batch[t] = image_2

    img_diff = image_batch.reshape(1,image_batch.shape[0], image_batch.shape[1], image_batch.shape[2], image_batch.shape[3])

    prediction = model.predict(img_diff)
    error = abs(prediction-y_train['real'][11+i])

    speed_dict['prediction'][11+i] = float(prediction[0][0])
    speed_dict['error'][11+i] = float(error[0][0])
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-106-f8cdfc2e2c28> in <module>()
# ----> 1 for i in tqdm_notebook(range(1)):
#       2     for t in range(timesteps):
#       3         ret, frame = cap.read()
#       4         if ret != True:
#       5             break
#
# /usr/local/lib/python3.5/dist-packages/tqdm/__init__.py in tqdm_notebook(*args, **kwargs)
#      17     """See tqdm._tqdm_notebook.tqdm_notebook for full documentation"""
#      18     from ._tqdm_notebook import tqdm_notebook as _tqdm_notebook
# ---> 19     return _tqdm_notebook(*args, **kwargs)
#      20
#      21
#
# /usr/local/lib/python3.5/dist-packages/tqdm/_tqdm.py in __new__(cls, *args, **kwargs)
#     445         if "_instances" not in cls.__dict__:
#     446             cls._instances = WeakSet()
# --> 447         with cls._lock:
#     448             cls._instances.add(instance)
#     449         # Create the monitoring thread
#
# ...

# %%
speed_dict_df = pd.DataFrame(speed_dict)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-102-aa4ad5296ff2> in <module>()
# ----> 1 speed_dict_df = prediction(85)
#
# <ipython-input-101-42a1716494c9> in prediction(v_idx)
#       6     length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
#       7     y=[]
# ----> 8     for i in tqdm(range(100)):
#       9         for t in range(timesteps):
#      10             ret, frame = cap.read()
#
# /usr/local/lib/python3.5/dist-packages/tqdm/_tqdm.py in __new__(cls, *args, **kwargs)
#     445         if "_instances" not in cls.__dict__:
#     446             cls._instances = WeakSet()
# --> 447         with cls._lock:
#     448             cls._instances.add(instance)
#     449         # Create the monitoring thread
#
# /usr/local/lib/python3.5/dist-packages/tqdm/_tqdm.py in __enter__(self)
#      75
#      76     def __enter__(self):
# ---> 77         self.acquire()
#      78
#      79     def __exit__(self, *exc):
#
# ...

# %%
def smooth(data):
    window_size = 25

    data['smooth_predicted_data'] = data['prediction'].rolling(window_size).mean()
    data['smooth_error'] = data.apply(lambda x: x['smooth_predicted_data'] - x['real'], axis=1)

    data['smooth_predicted_data'] = data.apply(lambda x: 
                                                            x['prediction'] if np.isnan(x['smooth_predicted_data'])
                                                           else x['smooth_predicted_data'],axis=1)

    data['smooth_error'] = data.apply(lambda x: x['error'] if np.isnan(x['smooth_error'])
                                                           else x['smooth_error'],axis=1)
    
    fig, ax = plt.subplots(figsize=(20,10))
    plt.plot(data.sort_values(['index'])[['index']], 
             data.sort_values(['index'])[['prediction']], 'bx')
    plt.plot(data.sort_values(['index'])[['index']], 
             data.sort_values(['index'])[['smooth_predicted_data']], 'g.')
    plt.plot(data.sort_values(['index'])[['index']], 
             data.sort_values(['index'])[['real']], 'r.')
    plt.xlabel('index (or time since start)')
    plt.ylabel('speed')
    plt.title('Predicted vs actual on train data')
    plt.legend(['predicted speed', (str(window_size) +' window average'), 'ground truth'], loc='upper right')
    plt.show()
    plt.close()
    
def show_graph(real_speed, predicted_speed):
    
    length =len(predicted_speed)
    
    real_speed = real_speed[:length]
    error = []
    predicted_speed = predicted_speed[:length]
    
    for i in range(length):
        er = abs(real_speed[i] - predicted_speed[i])
        error.append(er)
    
    meta_test_2df = pd.DataFrame({
        'image_index':list(range(length)),
        'speed':real_speed,
        'error':error,
        'predicted_speed':predicted_speed
    })

    window_size = 25

    meta_test_2df['smooth_predicted_speed'] = meta_test_2df['predicted_speed'].rolling(window_size).mean()
    meta_test_2df['smooth_error'] = meta_test_2df.apply(lambda x: x['smooth_predicted_speed'] - x['speed'], axis=1)

    meta_test_2df['smooth_predicted_speed'] = meta_test_2df.apply(lambda x:x['predicted_speed'] if np.isnan(x['smooth_predicted_speed']) else x['smooth_predicted_speed'],axis=1)

    meta_test_2df['smooth_error'] = meta_test_2df.apply(lambda x: x['error'] if np.isnan(x['smooth_error']) else x['smooth_error'],axis=1)

    fig, ax = plt.subplots(figsize=(20,10))
    plt.plot(meta_test_2df.sort_values(['image_index'])[['image_index']], 
             meta_test_2df.sort_values(['image_index'])[['predicted_speed']], 'bx')
    plt.plot(meta_test_2df.sort_values(['image_index'])[['image_index']], 
             meta_test_2df.sort_values(['image_index'])[['smooth_predicted_speed']], 'g.')
    plt.plot(meta_test_2df.sort_values(['image_index'])[['image_index']], 
             meta_test_2df.sort_values(['image_index'])[['speed']], 'r.')

    plt.xlabel('frame')
    plt.ylabel('speed')
    plt.title('Predicted on train data')
    plt.grid()
    plt.legend(['Predicted speed', '25 windows average','ground truth'], loc='upper right')
    plt.show()
    
    real = meta_test_2df.sort_values(['image_index'])[['speed']]
    error = meta_test_2df.sort_values(['image_index'])[['smooth_error']]
    pred = meta_test_2df.sort_values(['image_index'])[['smooth_predicted_speed']]
    
    return real, error, pred

# %%
data = pd.read_csv('../etc/daylight_257.csv')

# %%
data.shape
# Out:
# (257, 4)

# %%
data
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# 5             5             5
# 6             6             6
# 7             7             7
# 8             8             8
# 9             9             9
# 10           10            10
# 11           11            11
# 12           12            12
# 13           13            13
# 14           14            14
# 15           15            15
# 16           16            16
# 17           17            17
# 18           18            18
# 19           19            19
# 20           20            20
# 21           21            21
# 22           22            22
# 23           23            23
# 24           24            24
# 25           25            25
# 26           26            26
# 27           27            27
# 28           28            28
# 29           29            29
# ...
